# %% [markdown]
# miaomiao yang, shareable link:https://colab.research.google.com/drive/1HKNkf-f3mDRpE-38UxxErVkwtt5BhnFU#scrollTo=XidWZsxdT46q

# %% [markdown]
# ### Packges

# %% [markdown]
# midterm - data cleaning

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# final -  data visualization

# %%
from datascience import Table
import matplotlib
matplotlib.use('Agg')
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import warnings
warnings.simplefilter(action="ignore",category=FutureWarning)
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ###**Table 1**

# %% [markdown]
# ###Midterm

# %%
# define column names
li1 = ['Sort_order','Major_area','Notes','Country_code','Type',
                'sexes_1990','sexes_1995','sexes_2000','sexes_2005','sexes_2010','sexes_2015',
                'male_1990','male_1995','male_2000','male_2005','male_2010','male_2015',
                'female_1990','female_1995','female_2000','female_2005','female_2010','female_2015'
               ]

# %%
# load in excel data table
data1 = pd.read_excel('UN_MigrantStockTotal_2015.xlsx','Table 1',header=15)
data1.columns = li1
data1
# Out:
#      Sort_order                                         Major_area Notes  \
# 0             1                                              WORLD   NaN
# 1             2                                  Developed regions   (b)
# 2             3                                 Developing regions   (c)
# 3             4                          Least developed countries   (d)
# 4             5  Less developed regions excluding least develop...   NaN
# ..          ...                                                ...   ...
# 260         261                                              Samoa   NaN
# 261         262                                            Tokelau   NaN
# 262         263                                              Tonga   NaN
# 263         264                                             Tuvalu   NaN
# 264         265                          Wallis and Futuna Islands   NaN
#
#      Country_code Type sexes_1990 sexes_1995 sexes_2000 sexes_2005  \
# ...

# %%
# check the dtypes of the data frame column
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 23 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sort_order    265 non-null    int64
#  1   Major_area    265 non-null    object
#  2   Notes         26 non-null     object
#  3   Country_code  265 non-null    int64
#  4   Type          232 non-null    object
#  5   sexes_1990    265 non-null    object
#  6   sexes_1995    265 non-null    object
#  7   sexes_2000    265 non-null    object
#  8   sexes_2005    265 non-null    object
#  9   sexes_2010    265 non-null    int64
#  10  sexes_2015    265 non-null    int64
#  11  male_1990     265 non-null    object
#  12  male_1995     265 non-null    object
#  13  male_2000     265 non-null    object
#  14  male_2005     265 non-null    object
#  15  male_2010     265 non-null    int64
#  16  male_2015     265 non-null    int64
#  17  female_1990   265 non-null    object
# ...

# %%
# principle 5: a single observational units must be in one table
# split the dataset to have separate tables for "sexes","male", and "female".
# the 3 data sets will have "Major_area","Country_code","Type_of_data"
sexes = data1[['Major_area','Country_code','Type','sexes_1990','sexes_1995','sexes_2000','sexes_2005','sexes_2010','sexes_2015']]
sexes
# Out:
#                                             Major_area  Country_code Type  \
# 0                                                WORLD           900  NaN
# 1                                    Developed regions           901  NaN
# 2                                   Developing regions           902  NaN
# 3                            Least developed countries           941  NaN
# 4    Less developed regions excluding least develop...           934  NaN
# ..                                                 ...           ...  ...
# 260                                              Samoa           882    B
# 261                                            Tokelau           772    B
# 262                                              Tonga           776    B
# 263                                             Tuvalu           798    C
# 264                          Wallis and Futuna Islands           876    B
#
#     sexes_1990 sexes_1995 sexes_2000 sexes_2005  sexes_2010  sexes_2015
# ...

# %%
sexes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Major_area    265 non-null    object
#  1   Country_code  265 non-null    int64
#  2   Type          232 non-null    object
#  3   sexes_1990    265 non-null    object
#  4   sexes_1995    265 non-null    object
#  5   sexes_2000    265 non-null    object
#  6   sexes_2005    265 non-null    object
#  7   sexes_2010    265 non-null    int64
#  8   sexes_2015    265 non-null    int64
# dtypes: int64(3), object(6)
# memory usage: 18.8+ KB

# %% [markdown]
# both sexes

# %%
# principle 1: Some column headers are values, not variable names
tidy_sexes = sexes.melt(id_vars = ['Major_area','Country_code','Type'],
                        var_name = "sexes_year",value_name= "count")
tidy_sexes
# Out:
#                                              Major_area  Country_code Type  \
# 0                                                 WORLD           900  NaN
# 1                                     Developed regions           901  NaN
# 2                                    Developing regions           902  NaN
# 3                             Least developed countries           941  NaN
# 4     Less developed regions excluding least develop...           934  NaN
# ...                                                 ...           ...  ...
# 1585                                              Samoa           882    B
# 1586                                            Tokelau           772    B
# 1587                                              Tonga           776    B
# 1588                                             Tuvalu           798    C
# 1589                          Wallis and Futuna Islands           876    B
#
#       sexes_year      count
# 0     sexes_1990  152563212
# ...

# %%
tidy_sexes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1590 entries, 0 to 1589
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Major_area    1590 non-null   object
#  1   Country_code  1590 non-null   int64
#  2   Type          1392 non-null   object
#  3   sexes_year    1590 non-null   object
#  4   count         1590 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 62.2+ KB

# %%
#principle 2. each column needs to consist of one and only one varibale
#split sexes and year
tidy_sexes[['sex','year']]=tidy_sexes.sexes_year.str.split("_",expand=True)
tidy_sexes.drop(columns=['sexes_year'],axis=1,inplace=True)
tidy_sexes
# Out:
#                                              Major_area  Country_code Type  \
# 0                                                 WORLD           900  NaN
# 1                                     Developed regions           901  NaN
# 2                                    Developing regions           902  NaN
# 3                             Least developed countries           941  NaN
# 4     Less developed regions excluding least develop...           934  NaN
# ...                                                 ...           ...  ...
# 1585                                              Samoa           882    B
# 1586                                            Tokelau           772    B
# 1587                                              Tonga           776    B
# 1588                                             Tuvalu           798    C
# 1589                          Wallis and Futuna Islands           876    B
#
#           count    sex  year
# 0     152563212  sexes  1990
# ...

# %%
tidy_sexes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1590 entries, 0 to 1589
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Major_area    1590 non-null   object
#  1   Country_code  1590 non-null   int64
#  2   Type          1392 non-null   object
#  3   count         1590 non-null   object
#  4   sex           1590 non-null   object
#  5   year          1590 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 74.7+ KB

# %%
for col in ['count']:
    tidy_sexes.drop(tidy_sexes[tidy_sexes[col] == '..'].index, inplace=True)
tidy_sexes
# Out:
#                                              Major_area  Country_code Type  \
# 0                                                 WORLD           900  NaN
# 1                                     Developed regions           901  NaN
# 2                                    Developing regions           902  NaN
# 3                             Least developed countries           941  NaN
# 4     Less developed regions excluding least develop...           934  NaN
# ...                                                 ...           ...  ...
# 1585                                              Samoa           882    B
# 1586                                            Tokelau           772    B
# 1587                                              Tonga           776    B
# 1588                                             Tuvalu           798    C
# 1589                          Wallis and Futuna Islands           876    B
#
#           count    sex  year
# 0     152563212  sexes  1990
# ...

# %%
tidy_sexes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1575 entries, 0 to 1589
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Major_area    1575 non-null   object
#  1   Country_code  1575 non-null   int64
#  2   Type          1377 non-null   object
#  3   count         1575 non-null   object
#  4   sex           1575 non-null   object
#  5   year          1575 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 86.1+ KB

# %%
#drop rows with missing values
tidy_sexes.dropna(subset=['Type'],inplace=True)
tidy_sexes
# Out:
#                      Major_area  Country_code Type    count    sex  year
# 8                       Burundi           108  B R   333110  sexes  1990
# 9                       Comoros           174    B    14079  sexes  1990
# 10                     Djibouti           262  B R   122221  sexes  1990
# 11                      Eritrea           232    I    11848  sexes  1990
# 12                     Ethiopia           231  B R  1155390  sexes  1990
# ...                         ...           ...  ...      ...    ...   ...
# 1585                      Samoa           882    B     4929  sexes  2015
# 1586                    Tokelau           772    B      487  sexes  2015
# 1587                      Tonga           776    B     5731  sexes  2015
# 1588                     Tuvalu           798    C      141  sexes  2015
# 1589  Wallis and Futuna Islands           876    B     2849  sexes  2015
#
# [1377 rows x 6 columns]

# %%
tidy_sexes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1377 entries, 8 to 1589
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Major_area    1377 non-null   object
#  1   Country_code  1377 non-null   int64
#  2   Type          1377 non-null   object
#  3   count         1377 non-null   object
#  4   sex           1377 non-null   object
#  5   year          1377 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 75.3+ KB

# %% [markdown]
# male-only

# %%
male = data1[['Major_area','Country_code','Type','male_1990','male_1995','male_2000','male_2005','male_2010','male_2015']]
male
# Out:
#                                             Major_area  Country_code Type  \
# 0                                                WORLD           900  NaN
# 1                                    Developed regions           901  NaN
# 2                                   Developing regions           902  NaN
# 3                            Least developed countries           941  NaN
# 4    Less developed regions excluding least develop...           934  NaN
# ..                                                 ...           ...  ...
# 260                                              Samoa           882    B
# 261                                            Tokelau           772    B
# 262                                              Tonga           776    B
# 263                                             Tuvalu           798    C
# 264                          Wallis and Futuna Islands           876    B
#
#     male_1990 male_1995 male_2000 male_2005  male_2010  male_2015
# ...

# %%
tidy_male = male.melt(id_vars = ['Major_area','Country_code','Type'],
                      var_name = "male_year",value_name= "count")
tidy_male
# Out:
#                                              Major_area  Country_code Type  \
# 0                                                 WORLD           900  NaN
# 1                                     Developed regions           901  NaN
# 2                                    Developing regions           902  NaN
# 3                             Least developed countries           941  NaN
# 4     Less developed regions excluding least develop...           934  NaN
# ...                                                 ...           ...  ...
# 1585                                              Samoa           882    B
# 1586                                            Tokelau           772    B
# 1587                                              Tonga           776    B
# 1588                                             Tuvalu           798    C
# 1589                          Wallis and Futuna Islands           876    B
#
#       male_year     count
# 0     male_1990  77747510
# ...

# %%
#split sexes and year
tidy_male[['sex','year']]=tidy_male.male_year.str.split("_",expand=True)
tidy_male.drop(columns=['male_year'],axis=1,inplace=True)
tidy_male
# Out:
#                                              Major_area  Country_code Type  \
# 0                                                 WORLD           900  NaN
# 1                                     Developed regions           901  NaN
# 2                                    Developing regions           902  NaN
# 3                             Least developed countries           941  NaN
# 4     Less developed regions excluding least develop...           934  NaN
# ...                                                 ...           ...  ...
# 1585                                              Samoa           882    B
# 1586                                            Tokelau           772    B
# 1587                                              Tonga           776    B
# 1588                                             Tuvalu           798    C
# 1589                          Wallis and Futuna Islands           876    B
#
#          count   sex  year
# 0     77747510  male  1990
# ...

# %%
for col in ['count']:
    tidy_male.drop(tidy_male[tidy_male[col] == '..'].index, inplace=True)
tidy_male
# Out:
#                                              Major_area  Country_code Type  \
# 0                                                 WORLD           900  NaN
# 1                                     Developed regions           901  NaN
# 2                                    Developing regions           902  NaN
# 3                             Least developed countries           941  NaN
# 4     Less developed regions excluding least develop...           934  NaN
# ...                                                 ...           ...  ...
# 1585                                              Samoa           882    B
# 1586                                            Tokelau           772    B
# 1587                                              Tonga           776    B
# 1588                                             Tuvalu           798    C
# 1589                          Wallis and Futuna Islands           876    B
#
#          count   sex  year
# 0     77747510  male  1990
# ...

# %%
tidy_male.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1575 entries, 0 to 1589
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Major_area    1575 non-null   object
#  1   Country_code  1575 non-null   int64
#  2   Type          1377 non-null   object
#  3   count         1575 non-null   object
#  4   sex           1575 non-null   object
#  5   year          1575 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 86.1+ KB

# %%
#drop rows with missing values
tidy_male.dropna(subset=['Type'],inplace=True)
tidy_male
# Out:
#                      Major_area  Country_code Type   count   sex  year
# 8                       Burundi           108  B R  163267  male  1990
# 9                       Comoros           174    B    6717  male  1990
# 10                     Djibouti           262  B R   64242  male  1990
# 11                      Eritrea           232    I    6228  male  1990
# 12                     Ethiopia           231  B R  607284  male  1990
# ...                         ...           ...  ...     ...   ...   ...
# 1585                      Samoa           882    B    2469  male  2015
# 1586                    Tokelau           772    B     233  male  2015
# 1587                      Tonga           776    B    3127  male  2015
# 1588                     Tuvalu           798    C      78  male  2015
# 1589  Wallis and Futuna Islands           876    B    1438  male  2015
#
# [1377 rows x 6 columns]

# %% [markdown]
# female-only

# %%
female = data1[['Major_area','Country_code','Type','female_1990','female_1995','female_2000','female_2005','female_2010','female_2015']]
female
# Out:
#                                             Major_area  Country_code Type  \
# 0                                                WORLD           900  NaN
# 1                                    Developed regions           901  NaN
# 2                                   Developing regions           902  NaN
# 3                            Least developed countries           941  NaN
# 4    Less developed regions excluding least develop...           934  NaN
# ..                                                 ...           ...  ...
# 260                                              Samoa           882    B
# 261                                            Tokelau           772    B
# 262                                              Tonga           776    B
# 263                                             Tuvalu           798    C
# 264                          Wallis and Futuna Islands           876    B
#
#     female_1990 female_1995 female_2000 female_2005  female_2010  female_2015
# ...

# %%
tidy_female = female.melt(id_vars = ['Major_area','Country_code','Type'],
                          var_name = "female_year",value_name= "count")
tidy_female
# Out:
#                                              Major_area  Country_code Type  \
# 0                                                 WORLD           900  NaN
# 1                                     Developed regions           901  NaN
# 2                                    Developing regions           902  NaN
# 3                             Least developed countries           941  NaN
# 4     Less developed regions excluding least develop...           934  NaN
# ...                                                 ...           ...  ...
# 1585                                              Samoa           882    B
# 1586                                            Tokelau           772    B
# 1587                                              Tonga           776    B
# 1588                                             Tuvalu           798    C
# 1589                          Wallis and Futuna Islands           876    B
#
#       female_year     count
# 0     female_1990  74815702
# ...

# %%
tidy_female[['sex','year']]=tidy_female.female_year.str.split("_",expand=True)
tidy_female.drop(columns=['female_year'],axis=1,inplace=True)
tidy_female
# Out:
#                                              Major_area  Country_code Type  \
# 0                                                 WORLD           900  NaN
# 1                                     Developed regions           901  NaN
# 2                                    Developing regions           902  NaN
# 3                             Least developed countries           941  NaN
# 4     Less developed regions excluding least develop...           934  NaN
# ...                                                 ...           ...  ...
# 1585                                              Samoa           882    B
# 1586                                            Tokelau           772    B
# 1587                                              Tonga           776    B
# 1588                                             Tuvalu           798    C
# 1589                          Wallis and Futuna Islands           876    B
#
#          count     sex  year
# 0     74815702  female  1990
# ...

# %%
tidy_female.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1590 entries, 0 to 1589
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Major_area    1590 non-null   object
#  1   Country_code  1590 non-null   int64
#  2   Type          1392 non-null   object
#  3   count         1590 non-null   object
#  4   sex           1590 non-null   object
#  5   year          1590 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 74.7+ KB

# %%
for col in ['count']:
    tidy_female.drop(tidy_female[tidy_female[col] == '..'].index, inplace=True)
tidy_female
# Out:
#                                              Major_area  Country_code Type  \
# 0                                                 WORLD           900  NaN
# 1                                     Developed regions           901  NaN
# 2                                    Developing regions           902  NaN
# 3                             Least developed countries           941  NaN
# 4     Less developed regions excluding least develop...           934  NaN
# ...                                                 ...           ...  ...
# 1585                                              Samoa           882    B
# 1586                                            Tokelau           772    B
# 1587                                              Tonga           776    B
# 1588                                             Tuvalu           798    C
# 1589                          Wallis and Futuna Islands           876    B
#
#          count     sex  year
# 0     74815702  female  1990
# ...

# %%
tidy_female.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1575 entries, 0 to 1589
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Major_area    1575 non-null   object
#  1   Country_code  1575 non-null   int64
#  2   Type          1377 non-null   object
#  3   count         1575 non-null   object
#  4   sex           1575 non-null   object
#  5   year          1575 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 86.1+ KB

# %%
#drop rows with missing values
tidy_female.dropna(subset=['Type'],inplace=True)
tidy_female
# Out:
#                      Major_area  Country_code Type   count     sex  year
# 8                       Burundi           108  B R  169843  female  1990
# 9                       Comoros           174    B    7362  female  1990
# 10                     Djibouti           262  B R   57979  female  1990
# 11                      Eritrea           232    I    5620  female  1990
# 12                     Ethiopia           231  B R  548106  female  1990
# ...                         ...           ...  ...     ...     ...   ...
# 1585                      Samoa           882    B    2460  female  2015
# 1586                    Tokelau           772    B     254  female  2015
# 1587                      Tonga           776    B    2604  female  2015
# 1588                     Tuvalu           798    C      63  female  2015
# 1589  Wallis and Futuna Islands           876    B    1411  female  2015
#
# [1377 rows x 6 columns]

# %% [markdown]
# ###final

# %% [markdown]
# ###both sexes

# %%
fig1_1 = px.histogram(tidy_sexes, x = 'year' 
                              , y = 'count', 
                              facet_col = 'Type', 
                              facet_col_spacing = 0.01, 
                              title= " The Overall Distribution of Different Type of Data about Internatioanl Migrant Stock of Both Sexes from 1990-2015",
                              color = 'year', labels = {'year':'year', 'count': 'International Migrant Stock'})

fig1_1.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1]))
fig1_1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# cleaning modification for visualization
#  example： africa=estaern africa+middle africa+ northern africa+ south africa
# extract major area
continent1=data1.loc[[1,2,3,4,5,6,7,28,38,46,52,70,71,77,85,97,107,126,127,138,152,169,179,180,207,216,231,237,238,241,247,255],:]
continent1.head()
# Out:
#    Sort_order                                         Major_area Notes  \
# 1           2                                  Developed regions   (b)
# 2           3                                 Developing regions   (c)
# 3           4                          Least developed countries   (d)
# 4           5  Less developed regions excluding least develop...   NaN
# 5           6                                 Sub-Saharan Africa   (e)
#
#    Country_code Type sexes_1990 sexes_1995 sexes_2000 sexes_2005  sexes_2010  \
# 1           901  NaN   82378628   92306854  103375363  117181109   132560325
# 2           902  NaN   70184584   68494898   69327946   74087991    89153918
# 3           941  NaN   11075966   11711703   10077824    9809634    10018128
# 4           934  NaN   59105261   56778501   59244124   64272611    79130668
# 5           947  NaN   14690319   15324570   13716539   13951086    15496764
#
#    ...  male_2000 male_2005 male_2010 male_2015 female_1990  female_1995  \
# ...

# %%
continent_major=continent1.loc[[1,2,5,6,70,126,179,237],:]
continent_major.head()
# Out:
#     Sort_order          Major_area Notes  Country_code Type sexes_1990  \
# 1            2   Developed regions   (b)           901  NaN   82378628
# 2            3  Developing regions   (c)           902  NaN   70184584
# 5            6  Sub-Saharan Africa   (e)           947  NaN   14690319
# 6            7              Africa   NaN           903  NaN   15690623
# 70          71                Asia   NaN           935  NaN   48142261
#
#    sexes_1995 sexes_2000 sexes_2005  sexes_2010  ...  male_2000 male_2005  \
# 1    92306854  103375363  117181109   132560325  ...   50536796  57217777
# 2    68494898   69327946   74087991    89153918  ...   37348043  40648897
# 5    15324570   13716539   13951086    15496764  ...    7210452   7444048
# 6    16352814   14800306   15191146    16840014  ...    7856358   8231437
# 70   46548225   49340815   53371224    65914319  ...   26848671  29585231
#
#    male_2010 male_2015 female_1990  female_1995  female_2000 female_2005  \
# ...

# %%
sexes = continent_major[['Major_area','Country_code','Type','sexes_1990','sexes_1995','sexes_2000','sexes_2005','sexes_2010','sexes_2015']]
sexes.head()
# Out:
#             Major_area  Country_code Type sexes_1990 sexes_1995 sexes_2000  \
# 1    Developed regions           901  NaN   82378628   92306854  103375363
# 2   Developing regions           902  NaN   70184584   68494898   69327946
# 5   Sub-Saharan Africa           947  NaN   14690319   15324570   13716539
# 6               Africa           903  NaN   15690623   16352814   14800306
# 70                Asia           935  NaN   48142261   46548225   49340815
#
#    sexes_2005  sexes_2010  sexes_2015
# 1   117181109   132560325   140481955
# 2    74087991    89153918   103218281
# 5    13951086    15496764    18993986
# 6    15191146    16840014    20649557
# 70   53371224    65914319    75081125

# %%
tidy_sexes = sexes.melt(id_vars = ['Major_area','Country_code','Type'],
                        var_name = "sexes_year",value_name= "count")
tidy_sexes.head()
# Out:
#            Major_area  Country_code Type  sexes_year     count
# 0   Developed regions           901  NaN  sexes_1990  82378628
# 1  Developing regions           902  NaN  sexes_1990  70184584
# 2  Sub-Saharan Africa           947  NaN  sexes_1990  14690319
# 3              Africa           903  NaN  sexes_1990  15690623
# 4                Asia           935  NaN  sexes_1990  48142261

# %%
tidy_sexes[['sex','year']]=tidy_sexes.sexes_year.str.split("_",expand=True)
tidy_sexes.drop(columns=['sexes_year'],axis=1,inplace=True)
tidy_sexes.head()
# Out:
#            Major_area  Country_code Type     count    sex  year
# 0   Developed regions           901  NaN  82378628  sexes  1990
# 1  Developing regions           902  NaN  70184584  sexes  1990
# 2  Sub-Saharan Africa           947  NaN  14690319  sexes  1990
# 3              Africa           903  NaN  15690623  sexes  1990
# 4                Asia           935  NaN  48142261  sexes  1990

# %%
#splite tidy_sexes into developed regions, developing regions and continents
# use 'loc' is too waste time for complex data
selected_area = ['Developed regions','Developing regions']
developed_developing= tidy_sexes[tidy_sexes['Major_area'].isin(selected_area)]
developed_developing.head()
# Out:
#             Major_area  Country_code Type      count    sex  year
# 0    Developed regions           901  NaN   82378628  sexes  1990
# 1   Developing regions           902  NaN   70184584  sexes  1990
# 8    Developed regions           901  NaN   92306854  sexes  1995
# 9   Developing regions           902  NaN   68494898  sexes  1995
# 16   Developed regions           901  NaN  103375363  sexes  2000

# %%
# developed and developing areas
fig1_2 = px.line(developed_developing, x="year", y="count", color="Major_area", 
                 title ="The Changes of Internatioanl Migrant Stock of Developed and Developing Regions from 1990 to 2015",
                 labels={'Major_area':'Regions','count':'International Migrant Stock'}
        ,line_shape="spline", render_mode="svg")
fig1_2.update_traces(mode="markers+lines")
fig1_2.update_yaxes(showticklabels=True)
fig1_2.update_xaxes(showticklabels=True)
fig1_2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
selected_area = ['Asia','Africa','Sub-Saharan Africa','Europe','Latin America and the Caribbean','Oceania']
major_continents = tidy_sexes[tidy_sexes['Major_area'].isin(selected_area)]
major_continents.head()
# Out:
#                         Major_area  Country_code Type     count    sex  year
# 2               Sub-Saharan Africa           947  NaN  14690319  sexes  1990
# 3                           Africa           903  NaN  15690623  sexes  1990
# 4                             Asia           935  NaN  48142261  sexes  1990
# 5                           Europe           908  NaN  49219200  sexes  1990
# 6  Latin America and the Caribbean           904  NaN   7169728  sexes  1990

# %%
# continents
fig1_3 = px.line(major_continents, x="year", y="count", color="Major_area", 
                 title ="The Changes of Internatioanl Migrant Stock of Different Continents from 1990 to 2015",
        labels={'Major_area':'Continents','count':'International Migrant Stock'},line_shape="spline", render_mode="svg")
fig1_3.update_traces(mode="markers+lines")
fig1_3.update_yaxes(showticklabels=True)
fig1_3.update_xaxes(showticklabels=True)
fig1_3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### **Table 2**

# %% [markdown]
# ###midterm

# %%
data2 = pd.read_excel('UN_MigrantStockTotal_2015.xlsx','Table 2',header=15)
li2 = ['Sort_order','Major_area','Notes','Country_code',
                'sexes_1990','sexes_1995','sexes_2000','sexes_2005','sexes_2010','sexes_2015',
                'male_1990','male_1995','male_2000','male_2005','male_2010','male_2015',
                'female_1990','female_1995','female_2000','female_2005','female_2010','female_2015'
               ]
data2.columns = li2
data2.head()
# Out:
#    Sort_order                                         Major_area Notes  \
# 0           1                                              WORLD   NaN
# 1           2                                  Developed regions   (b)
# 2           3                                 Developing regions   (c)
# 3           4                          Least developed countries   (d)
# 4           5  Less developed regions excluding least develop...   NaN
#
#    Country_code   sexes_1990   sexes_1995   sexes_2000   sexes_2005  \
# 0           900  5309667.699  5735123.084  6126622.121  6519635.850
# 1           901  1144463.062  1169761.211  1188811.731  1208919.509
# 2           902  4165204.637  4565361.873  4937810.390  5310716.341
# 3           941   510057.629   585189.354   664386.087   752804.951
# 4           934  3655147.008  3980172.519  4273424.303  4557911.390
#
#     sexes_2010   sexes_2015  ...    male_2000    male_2005    male_2010  \
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 22 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sort_order    265 non-null    int64
#  1   Major_area    265 non-null    object
#  2   Notes         26 non-null     object
#  3   Country_code  265 non-null    int64
#  4   sexes_1990    265 non-null    float64
#  5   sexes_1995    265 non-null    float64
#  6   sexes_2000    265 non-null    float64
#  7   sexes_2005    265 non-null    float64
#  8   sexes_2010    265 non-null    float64
#  9   sexes_2015    265 non-null    float64
#  10  male_1990     265 non-null    object
#  11  male_1995     265 non-null    object
#  12  male_2000     265 non-null    object
#  13  male_2005     265 non-null    object
#  14  male_2010     265 non-null    object
#  15  male_2015     265 non-null    object
#  16  female_1990   265 non-null    object
#  17  female_1995   265 non-null    object
# ...

# %%
data2.drop(columns=['Notes','Sort_order'],axis=1,inplace=True)
data2
# Out:
#                                             Major_area  Country_code  \
# 0                                                WORLD           900
# 1                                    Developed regions           901
# 2                                   Developing regions           902
# 3                            Least developed countries           941
# 4    Less developed regions excluding least develop...           934
# ..                                                 ...           ...
# 260                                              Samoa           882
# 261                                            Tokelau           772
# 262                                              Tonga           776
# 263                                             Tuvalu           798
# 264                          Wallis and Futuna Islands           876
#
#       sexes_1990   sexes_1995   sexes_2000   sexes_2005   sexes_2010  \
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Major_area    265 non-null    object
#  1   Country_code  265 non-null    int64
#  2   sexes_1990    265 non-null    float64
#  3   sexes_1995    265 non-null    float64
#  4   sexes_2000    265 non-null    float64
#  5   sexes_2005    265 non-null    float64
#  6   sexes_2010    265 non-null    float64
#  7   sexes_2015    265 non-null    float64
#  8   male_1990     265 non-null    object
#  9   male_1995     265 non-null    object
#  10  male_2000     265 non-null    object
#  11  male_2005     265 non-null    object
#  12  male_2010     265 non-null    object
#  13  male_2015     265 non-null    object
#  14  female_1990   265 non-null    object
#  15  female_1995   265 non-null    object
#  16  female_2000   265 non-null    object
#  17  female_2005   265 non-null    object
# ...

# %%
tidy_data2 = data2.melt(id_vars = ['Major_area','Country_code',],var_name = 'sex_year',value_name='population')
tidy_data2
# Out:
#                                              Major_area  Country_code  \
# 0                                                 WORLD           900
# 1                                     Developed regions           901
# 2                                    Developing regions           902
# 3                             Least developed countries           941
# 4     Less developed regions excluding least develop...           934
# ...                                                 ...           ...
# 4765                                              Samoa           882
# 4766                                            Tokelau           772
# 4767                                              Tonga           776
# 4768                                             Tuvalu           798
# 4769                          Wallis and Futuna Islands           876
#
#          sex_year   population
# 0      sexes_1990  5309667.699
# 1      sexes_1990  1144463.062
# ...

# %%
tidy_data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4770 entries, 0 to 4769
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Major_area    4770 non-null   object
#  1   Country_code  4770 non-null   int64
#  2   sex_year      4770 non-null   object
#  3   population    4770 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 149.2+ KB

# %%
tidy_data2[['sex','year']]=tidy_data2.sex_year.str.split("_",expand=True)
tidy_data2
# Out:
#                                              Major_area  Country_code  \
# 0                                                 WORLD           900
# 1                                     Developed regions           901
# 2                                    Developing regions           902
# 3                             Least developed countries           941
# 4     Less developed regions excluding least develop...           934
# ...                                                 ...           ...
# 4765                                              Samoa           882
# 4766                                            Tokelau           772
# 4767                                              Tonga           776
# 4768                                             Tuvalu           798
# 4769                          Wallis and Futuna Islands           876
#
#          sex_year   population     sex  year
# 0      sexes_1990  5309667.699   sexes  1990
# ...

# %%
tidy_data2.drop(columns=['sex_year'],axis=1,inplace=True)
tidy_data2
# Out:
#                                              Major_area  Country_code  \
# 0                                                 WORLD           900
# 1                                     Developed regions           901
# 2                                    Developing regions           902
# 3                             Least developed countries           941
# 4     Less developed regions excluding least develop...           934
# ...                                                 ...           ...
# 4765                                              Samoa           882
# 4766                                            Tokelau           772
# 4767                                              Tonga           776
# 4768                                             Tuvalu           798
# 4769                          Wallis and Futuna Islands           876
#
#        population     sex  year
# 0     5309667.699   sexes  1990
# 1     1144463.062   sexes  1990
# ...

# %%
for col in ['population']:
    tidy_data2.drop(tidy_data2[tidy_data2[col] == '..'].index, inplace=True)
tidy_data2
# Out:
#                                              Major_area  Country_code  \
# 0                                                 WORLD           900
# 1                                     Developed regions           901
# 2                                    Developing regions           902
# 3                             Least developed countries           941
# 4     Less developed regions excluding least develop...           934
# ...                                                 ...           ...
# 4756                   Micronesia (Federated States of)           583
# 4760                                          Polynesia           957
# 4763                                   French Polynesia           258
# 4765                                              Samoa           882
# 4767                                              Tonga           776
#
#        population     sex  year
# 0     5309667.699   sexes  1990
# 1     1144463.062   sexes  1990
# ...

# %%
tidy_data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4386 entries, 0 to 4767
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Major_area    4386 non-null   object
#  1   Country_code  4386 non-null   int64
#  2   population    4386 non-null   object
#  3   sex           4386 non-null   object
#  4   year          4386 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 205.6+ KB

# %% [markdown]
# ###final

# %%
# total population
f2=tidy_data2
f2.head()
# Out:
#                                           Major_area  Country_code  \
# 0                                              WORLD           900
# 1                                  Developed regions           901
# 2                                 Developing regions           902
# 3                          Least developed countries           941
# 4  Less developed regions excluding least develop...           934
#
#     population    sex  year
# 0  5309667.699  sexes  1990
# 1  1144463.062  sexes  1990
# 2  4165204.637  sexes  1990
# 3   510057.629  sexes  1990
# 4  3655147.008  sexes  1990

# %%
#splite developed, developing area; major contients, and countries.
selected_area2 = ['Developed regions','Developing regions']
developed_developing= f2[f2['Major_area'].isin(selected_area2)]
developed_developing.head()
# Out:
#              Major_area  Country_code   population    sex  year
# 1     Developed regions           901  1144463.062  sexes  1990
# 2    Developing regions           902  4165204.637  sexes  1990
# 266   Developed regions           901  1169761.211  sexes  1995
# 267  Developing regions           902  4565361.873  sexes  1995
# 531   Developed regions           901  1188811.731  sexes  2000

# %%
fig2_1 = px.bar(developed_developing, x="Major_area", y="population", color = "Major_area", facet_col="year", facet_row = "sex", facet_row_spacing= 0.2,
                   title = "Comparision of Total Population of Developed and Developing Region from 1990-2015",
                   labels={"population":"Population","Major_area":"Regions"})
fig2_1.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1]))
fig2_1.update_xaxes(showticklabels=True)
fig2_1.update_yaxes(showticklabels=True)
fig2_1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
selected_area2 = ['Asia','Africa','Sub-Saharan Africa','Europe','Latin America and the Caribbean','Oceania']
major_continents = f2[f2['Major_area'].isin(selected_area2)]
major_continents.head()
# Out:
#                           Major_area  Country_code   population    sex  year
# 5                 Sub-Saharan Africa           947   491497.691  sexes  1990
# 6                             Africa           903   631614.304  sexes  1990
# 70                              Asia           935  3202474.692  sexes  1990
# 126                           Europe           908   721086.311  sexes  1990
# 179  Latin America and the Caribbean           904   446888.767  sexes  1990

# %%
selected_sexes = ['sexes']
both_sexes = major_continents[major_continents['sex'].isin(selected_sexes)]
both_sexes.head()
# Out:
#                           Major_area  Country_code   population    sex  year
# 5                 Sub-Saharan Africa           947   491497.691  sexes  1990
# 6                             Africa           903   631614.304  sexes  1990
# 70                              Asia           935  3202474.692  sexes  1990
# 126                           Europe           908   721086.311  sexes  1990
# 179  Latin America and the Caribbean           904   446888.767  sexes  1990

# %%
selected_area = ['Developed regions','Developing regions','Asia','Africa','Sub-Saharan Africa','Europe','Latin America and the Caribbean','Oceania']
regions_continents = f2[f2['Major_area'].isin(selected_area)]
regions_continents.head()
# Out:
#             Major_area  Country_code   population    sex  year
# 1    Developed regions           901  1144463.062  sexes  1990
# 2   Developing regions           902  4165204.637  sexes  1990
# 5   Sub-Saharan Africa           947   491497.691  sexes  1990
# 6               Africa           903   631614.304  sexes  1990
# 70                Asia           935  3202474.692  sexes  1990

# %%
# use scatter would be the best choice, however, due to the 'loc' function which 
# is to select area, caz 'Major_area' desn't show properly.as a second choice, use country_code.
fig2_2_1 = px.scatter(regions_continents, x="year", y="population",facet_col ='Major_area',color = 'sex',
                title="Comparision of Regions' and Continents' Population Rising Tendency by Genders from 1990-2015",
                 labels = {'year' :'year', 'population':'total population'})
fig2_2_1 .update_traces(mode="markers+lines")
fig2_2_1.update_xaxes(matches=None)
fig2_2_1.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1]))
fig2_2_1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# use scatter would be the best choice, however, due to the 'loc' function which 
# is to select area, caz 'Major_area' desn't show properly.as a second choice, use country_code.
fig2_2_2 = px.scatter(regions_continents, x="year", y="population",facet_col ='sex',color = 'Major_area',
                title="Comparision of Regions' and Continents' Population Rising Tendency by Genders from 1990-2015",
                 labels = {'year' :'year', 'population':'total population'})
fig2_2_2.update_traces(mode="markers+lines")
fig2_2_2.update_xaxes(matches=None)
fig2_2_2.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1]))
fig2_2_2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# use scatter would be the best choice, however, due to the 'loc' function which 
# is to select area, caz 'Major_area' desn't show properly.as a second choice, use country_code.
fig2_3 = px.bar(regions_continents, x="Major_area", y="population",facet_col ='year',facet_row = 'sex',color = 'Major_area',
                facet_row_spacing=0.007, height=1000, width=1200,
                title="Overveiw of Total population of Diffferent Regions and Continenets by Genders from 1990-2015",
                labels = {'Major_area' :'Regions', 'population':'total population'})
fig2_3.update_xaxes(matches=None)
fig2_3.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1]))
fig2_3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### table 3

# %% [markdown]
# ### midterm

# %%
li3 = ['Sort_order','Major_area','Notes','Country_code','Type_of_data_(a)',
                'sexes_1990','sexes_1995','sexes_2000','sexes_2005','sexes_2010','sexes_2015',
                'male_1990','male_1995','male_2000','male_2005','male_2010','male_2015',
                'female_1990','female_1995','female_2000','female_2005','female_2010','female_2015'
               ]

# %%
data3 = pd.read_excel('UN_MigrantStockTotal_2015.xlsx','Table 3',header=15)
data3.columns = li3
data3.head()
# Out:
#    Sort_order                                         Major_area Notes  \
# 0           1                                              WORLD   NaN
# 1           2                                  Developed regions   (b)
# 2           3                                 Developing regions   (c)
# 3           4                          Least developed countries   (d)
# 4           5  Less developed regions excluding least develop...   NaN
#
#    Country_code Type_of_data_(a) sexes_1990 sexes_1995 sexes_2000 sexes_2005  \
# 0           900              NaN    2.87331   2.803806   2.818899   2.933739
# 1           901              NaN   7.198015   7.891085   8.695688   9.693045
# 2           902              NaN   1.685021   1.500317   1.404022   1.395066
# 3           941              NaN   2.171513   2.001353   1.516863   1.303078
# 4           934              NaN   1.617042   1.426534   1.386338   1.410133
#
# ...

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Sort_order        265 non-null    int64
#  1   Major_area        265 non-null    object
#  2   Notes             26 non-null     object
#  3   Country_code      265 non-null    int64
#  4   Type_of_data_(a)  232 non-null    object
#  5   sexes_1990        265 non-null    object
#  6   sexes_1995        265 non-null    object
#  7   sexes_2000        265 non-null    object
#  8   sexes_2005        265 non-null    object
#  9   sexes_2010        265 non-null    float64
#  10  sexes_2015        265 non-null    float64
#  11  male_1990         265 non-null    object
#  12  male_1995         265 non-null    object
#  13  male_2000         265 non-null    object
#  14  male_2005         265 non-null    object
#  15  male_2010         265 non-null    object
# ...

# %%
data3.drop(columns=['Notes','Sort_order'],axis=1,inplace=True)
data3.head()
# Out:
#                                           Major_area  Country_code  \
# 0                                              WORLD           900
# 1                                  Developed regions           901
# 2                                 Developing regions           902
# 3                          Least developed countries           941
# 4  Less developed regions excluding least develop...           934
#
#   Type_of_data_(a) sexes_1990 sexes_1995 sexes_2000 sexes_2005  sexes_2010  \
# 0              NaN    2.87331   2.803806   2.818899   2.933739    3.199467
# 1              NaN   7.198015   7.891085   8.695688   9.693045   10.747765
# 2              NaN   1.685021   1.500317   1.404022   1.395066    1.565106
# 3              NaN   2.171513   2.001353   1.516863   1.303078    1.182422
# 4              NaN   1.617042   1.426534   1.386338   1.410133    1.631865
#
#    sexes_2015 male_1990  ... male_2000 male_2005  male_2010  male_2015  \
# ...

# %%
data3.dropna(subset=['Type_of_data_(a)'],inplace=True)

# %%
tidy_data3 = data3.melt(id_vars = ['Major_area','Country_code','Type_of_data_(a)'],var_name='sex_year',value_name='percentage')
tidy_data3.head()
# Out:
#   Major_area  Country_code Type_of_data_(a)    sex_year percentage
# 0    Burundi           108              B R  sexes_1990   5.934467
# 1    Comoros           174                B  sexes_1990   3.391353
# 2   Djibouti           262              B R  sexes_1990  20.773307
# 3    Eritrea           232                I  sexes_1990   0.377435
# 4   Ethiopia           231              B R  sexes_1990   2.404203

# %%
tidy_data3[['sex','year']]=tidy_data3.sex_year.str.split("_",expand=True)
tidy_data3.drop(columns='sex_year',axis=1,inplace=True)
tidy_data3.head()
# Out:
#   Major_area  Country_code Type_of_data_(a) percentage    sex  year
# 0    Burundi           108              B R   5.934467  sexes  1990
# 1    Comoros           174                B   3.391353  sexes  1990
# 2   Djibouti           262              B R  20.773307  sexes  1990
# 3    Eritrea           232                I   0.377435  sexes  1990
# 4   Ethiopia           231              B R   2.404203  sexes  1990

# %%
for col in ['percentage']:
    tidy_data3.drop(tidy_data3[tidy_data3[col] == '..'].index, inplace=True)
tidy_data3.head()
# Out:
#   Major_area  Country_code Type_of_data_(a) percentage    sex  year
# 0    Burundi           108              B R   5.934467  sexes  1990
# 1    Comoros           174                B   3.391353  sexes  1990
# 2   Djibouti           262              B R  20.773307  sexes  1990
# 3    Eritrea           232                I   0.377435  sexes  1990
# 4   Ethiopia           231              B R   2.404203  sexes  1990

# %%
tidy_data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3749 entries, 0 to 4173
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Major_area        3749 non-null   object
#  1   Country_code      3749 non-null   int64
#  2   Type_of_data_(a)  3749 non-null   object
#  3   percentage        3749 non-null   object
#  4   sex               3749 non-null   object
#  5   year              3749 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 205.0+ KB

# %% [markdown]
# ### final

# %%
tidy_data3.head()
# Out:
#   Major_area  Country_code Type_of_data_(a) percentage    sex  year
# 0    Burundi           108              B R   5.934467  sexes  1990
# 1    Comoros           174                B   3.391353  sexes  1990
# 2   Djibouti           262              B R  20.773307  sexes  1990
# 3    Eritrea           232                I   0.377435  sexes  1990
# 4   Ethiopia           231              B R   2.404203  sexes  1990

# %%
#splite tidy_data3 into sexes and male_female
#both sexes
sexes= ['sexes']
both_sexes = tidy_data3[tidy_data3['sex'].isin(sexes)]
both_sexes.head()
# Out:
#   Major_area  Country_code Type_of_data_(a) percentage    sex  year
# 0    Burundi           108              B R   5.934467  sexes  1990
# 1    Comoros           174                B   3.391353  sexes  1990
# 2   Djibouti           262              B R  20.773307  sexes  1990
# 3    Eritrea           232                I   0.377435  sexes  1990
# 4   Ethiopia           231              B R   2.404203  sexes  1990

# %% [markdown]
# ### both sexes

# %%
# this table look at the % changes of all countires for both sexes
both_sexes.query("Major_area =='Major_area'")
fig3_1 = px.line(both_sexes, x="year", y="percentage", facet_col="Major_area", facet_col_wrap=7,
              facet_row_spacing=0.01, 
              facet_col_spacing=0.02, 
              height=6000, width=2000,
              title="Different Countries' International migrant Stock Percentage Changes for Both Sexes from 1990 to 2015",
              labels = {'Major_area':'Country'})
fig3_1.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1]))
fig3_1.update_xaxes(showticklabels=True)
fig3_1.update_yaxes(showticklabels=True)
fig3_1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### male&female

# %%
# this table look at the comparision of male and female's % change in all countires.
sexes= ['male','female']
male_female = tidy_data3[tidy_data3['sex'].isin(sexes)]
male_female
# Out:
#                             Major_area  Country_code Type_of_data_(a)  \
# 1392                           Burundi           108              B R
# 1393                           Comoros           174                B
# 1394                          Djibouti           262              B R
# 1395                           Eritrea           232                I
# 1396                          Ethiopia           231              B R
# ...                                ...           ...              ...
# 4161                          Kiribati           296                B
# 4163  Micronesia (Federated States of)           583                B
# 4169                  French Polynesia           258                B
# 4171                             Samoa           882                B
# 4173                             Tonga           776                B
#
#      percentage     sex  year
# 1392   5.926147    male  1990
# 1393   3.226039    male  1990
# 1394  21.708292    male  1990
# ...

# %%
male_female.query("Major_area =='Major_area'")
fig3_2 = px.line(male_female, x="year", y="percentage", facet_col="Major_area", facet_col_wrap=5,
              color = 'sex',
              facet_row_spacing=0.01, 
              facet_col_spacing=0.02, 
              height=6000, width=1500,
              title="Different Countries' International migrant Stock Percentage Changes by Genders from 1990 to 2015",
              labels = {'Major_area':'Country'})
fig3_2.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1]))
fig3_2.update_xaxes(showticklabels=True)
fig3_2.update_yaxes(showticklabels=True)
fig3_2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### table 4

# %% [markdown]
# ###midterm

# %%
li4 = ['Sort_order','Major_area','Notes','Country_code','Type',
                'female_1990','female_1995','female_2000','female_2005','female_2010','female_2015'
               ]

# %%
data4 = pd.read_excel('UN_MigrantStockTotal_2015.xlsx','Table 4',header=15)
data4.columns = li4
data4
# Out:
#      Sort_order                                         Major_area Notes  \
# 0             1                                              WORLD   NaN
# 1             2                                  Developed regions   (b)
# 2             3                                 Developing regions   (c)
# 3             4                          Least developed countries   (d)
# 4             5  Less developed regions excluding least develop...   NaN
# ..          ...                                                ...   ...
# 260         261                                              Samoa   NaN
# 261         262                                            Tokelau   NaN
# 262         263                                              Tonga   NaN
# 263         264                                             Tuvalu   NaN
# 264         265                          Wallis and Futuna Islands   NaN
#
#      Country_code Type female_1990 female_1995 female_2000 female_2005  \
# ...

# %%
data4.drop(columns=['Notes','Sort_order'],axis=1,inplace=True)
data4
# Out:
#                                             Major_area  Country_code Type  \
# 0                                                WORLD           900  NaN
# 1                                    Developed regions           901  NaN
# 2                                   Developing regions           902  NaN
# 3                            Least developed countries           941  NaN
# 4    Less developed regions excluding least develop...           934  NaN
# ..                                                 ...           ...  ...
# 260                                              Samoa           882    B
# 261                                            Tokelau           772    B
# 262                                              Tonga           776    B
# 263                                             Tuvalu           798    C
# 264                          Wallis and Futuna Islands           876    B
#
#     female_1990 female_1995 female_2000 female_2005  female_2010  female_2015
# ...

# %%
data4.dropna(subset=['Type'],inplace=True)

# %%
for col in [ 'female_1990','female_1995','female_2000','female_2005','female_2010','female_2015']:
    data4.drop(data4[data4[col] == '..'].index, inplace=True)

# %%
data4
# Out:
#                     Major_area  Country_code Type female_1990 female_1995  \
# 8                      Burundi           108  B R   50.987061   51.279757
# 9                      Comoros           174    B   52.290646   52.550398
# 10                    Djibouti           262  B R   47.437838   47.405136
# 11                     Eritrea           232    I   47.434166   47.241935
# 12                    Ethiopia           231  B R   47.439047   47.438977
# ..                         ...           ...  ...         ...         ...
# 260                      Samoa           882    B   47.244564   47.784406
# 261                    Tokelau           772    B   44.444444   44.736842
# 262                      Tonga           776    B   48.883545   47.525962
# 263                     Tuvalu           798    C   43.396226   43.726236
# 264  Wallis and Futuna Islands           876    B   48.216833   48.869048
#
#     female_2000 female_2005  female_2010  female_2015
# ...

# %%
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 228 entries, 8 to 264
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Major_area    228 non-null    object
#  1   Country_code  228 non-null    int64
#  2   Type          228 non-null    object
#  3   female_1990   228 non-null    object
#  4   female_1995   228 non-null    object
#  5   female_2000   228 non-null    object
#  6   female_2005   228 non-null    object
#  7   female_2010   228 non-null    float64
#  8   female_2015   228 non-null    float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 25.9+ KB

# %%
tidy_data4 = data4.melt(id_vars = ['Major_area','Country_code','Type'],var_name = "sex_year",value_name= "percentage")
tidy_data4
# Out:
#                      Major_area  Country_code Type     sex_year percentage
# 0                       Burundi           108  B R  female_1990  50.987061
# 1                       Comoros           174    B  female_1990  52.290646
# 2                      Djibouti           262  B R  female_1990  47.437838
# 3                       Eritrea           232    I  female_1990  47.434166
# 4                      Ethiopia           231  B R  female_1990  47.439047
# ...                         ...           ...  ...          ...        ...
# 1363                      Samoa           882    B  female_2015  49.908704
# 1364                    Tokelau           772    B  female_2015  52.156057
# 1365                      Tonga           776    B  female_2015  45.437096
# 1366                     Tuvalu           798    C  female_2015  44.680851
# 1367  Wallis and Futuna Islands           876    B  female_2015   49.52615
#
# [1368 rows x 5 columns]

# %%
tidy_data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1368 entries, 0 to 1367
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Major_area    1368 non-null   object
#  1   Country_code  1368 non-null   int64
#  2   Type          1368 non-null   object
#  3   sex_year      1368 non-null   object
#  4   percentage    1368 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 53.6+ KB

# %%
tidy_data4[['sex','year']]=tidy_data4.sex_year.str.split("_",expand=True)
tidy_data4.drop(columns='sex_year',axis=1,inplace=True)
tidy_data4
# Out:
#                      Major_area  Country_code Type percentage     sex  year
# 0                       Burundi           108  B R  50.987061  female  1990
# 1                       Comoros           174    B  52.290646  female  1990
# 2                      Djibouti           262  B R  47.437838  female  1990
# 3                       Eritrea           232    I  47.434166  female  1990
# 4                      Ethiopia           231  B R  47.439047  female  1990
# ...                         ...           ...  ...        ...     ...   ...
# 1363                      Samoa           882    B  49.908704  female  2015
# 1364                    Tokelau           772    B  52.156057  female  2015
# 1365                      Tonga           776    B  45.437096  female  2015
# 1366                     Tuvalu           798    C  44.680851  female  2015
# 1367  Wallis and Futuna Islands           876    B   49.52615  female  2015
#
# [1368 rows x 6 columns]

# %%
tidy_data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1368 entries, 0 to 1367
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Major_area    1368 non-null   object
#  1   Country_code  1368 non-null   int64
#  2   Type          1368 non-null   object
#  3   percentage    1368 non-null   object
#  4   sex           1368 non-null   object
#  5   year          1368 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 64.2+ KB

# %% [markdown]
# ###final

# %% [markdown]
# ###boxplot

# %%
tidy_data4.head()
# Out:
#   Major_area  Country_code Type percentage     sex  year
# 0    Burundi           108  B R  50.987061  female  1990
# 1    Comoros           174    B  52.290646  female  1990
# 2   Djibouti           262  B R  47.437838  female  1990
# 3    Eritrea           232    I  47.434166  female  1990
# 4   Ethiopia           231  B R  47.439047  female  1990

# %%
f4_1_1 =plt.figure(figsize = (12,7))
f4_1_1 = sns.boxplot(data=tidy_data4, x="percentage", y="year", hue="year",
             dodge = False,fliersize = 3,linewidth = 0.5,
            flierprops ={'marker':'x'}).set(title='Overall patterns of Female migrants as a percentage of the international migrant stock from 1990 to 2015', 
                           xlabel ='Female Migrant Percentage', ylabel ='year')
f4_1_1 =sns.set_style('white')
f4_1_1 =sns.set_palette('flare')
f4_1_1 =sns.set(rc={'figure.figsize':(30,12)})
f4_1_1 =plt.show()

# %%
f4_1_2 =plt.figure(figsize = (12,7))
f4_1_2 = sns.boxplot(data=tidy_data4, x="year", y="percentage", hue="year",
             dodge = False,fliersize = 3,linewidth = 0.5,
            flierprops ={'marker':'x'}).set(title='Overall patterns of Female migrants as a percentage of the international migrant stock from 1990 to 2015', 
                           xlabel ='Female Migrant Percentage', ylabel ='year')
f4_1_2 =sns.set_style('white')
f4_1_2  =sns.set_palette('flare')
f4_1_2  =sns.set(rc={'figure.figsize':(30,12)})
f4_1_2  =plt.show()

# %%
fig4_1_3 = px.box(tidy_data4, x="year", y="percentage",
                title="Overall patterns of Female migrants as a percentage of the international migrant stock from 1990 to 2015'",
                 labels = {'year' :'year', 'percentage':'Female Migrant Percentage'})
fig4_1_3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###histoplot

# %%
tidy_data4.head()
# Out:
#   Major_area  Country_code Type percentage     sex  year
# 0    Burundi           108  B R  50.987061  female  1990
# 1    Comoros           174    B  52.290646  female  1990
# 2   Djibouti           262  B R  47.437838  female  1990
# 3    Eritrea           232    I  47.434166  female  1990
# 4   Ethiopia           231  B R  47.439047  female  1990

# %%
# new data cleaning for visualization
f4 = pd.read_excel('UN_MigrantStockTotal_2015.xlsx','Table 4',header=15)
f4.columns = li4
f4.drop(columns=['Notes','Sort_order'],axis=1,inplace=True)
for col in [ 'female_1990','female_1995','female_2000','female_2005','female_2010','female_2015']:
    f4.drop(f4[f4[col] == '..'].index, inplace=True)
f4 = f4.melt(id_vars = ['Major_area','Country_code','Type'],var_name = "sex_year",value_name= "percentage")
f4[['sex','year']]=f4.sex_year.str.split("_",expand=True)
f4.drop(columns='sex_year',axis=1,inplace=True)
f4.head()
# Out:
#                                           Major_area  Country_code Type  \
# 0                                              WORLD           900  NaN
# 1                                  Developed regions           901  NaN
# 2                                 Developing regions           902  NaN
# 3                          Least developed countries           941  NaN
# 4  Less developed regions excluding least develop...           934  NaN
#
#   percentage     sex  year
# 0   49.03915  female  1990
# 1  51.123977  female  1990
# 2  46.592099  female  1990
# 3  47.261155  female  1990
# 4  46.466684  female  1990

# %%
# splite regions, continents, and countires.
selected_area4 = ['Developed regions','Developing regions']
regions = f4[f4['Major_area'].isin(selected_area4)]
regions.drop(columns=['Country_code','Type','sex'],axis=1,inplace=True)
regions.head()
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              Major_area percentage  year
# 1     Developed regions  51.123977  1990
# 2    Developing regions  46.592099  1990
# 262   Developed regions  51.149024  1995
# 263  Developing regions  46.500135  1995
# 523   Developed regions  51.113307  2000

# %%
f4_2 = plt.figure(figsize = (8,5))
f4_2 = sns.histplot(regions, x="year", y = "percentage",hue="Major_area", 
             kde=True).set(title='Trends of Female Migrants Percentage of Developed and Developing Regions from 1990 to 2015', 
                           xlabel ='year', ylabel ='Female Migrant Percentage')
f4_2 = plt.show()

# %%
selected_area4 = ['Asia','Africa','Sub-Saharan Africa','Europe','Latin America and the Caribbean','Oceania']
continents = f4[f4['Major_area'].isin(selected_area4)]
continents.head()
# Out:
#                           Major_area  Country_code Type percentage     sex  \
# 5                 Sub-Saharan Africa           947  NaN  47.276121  female
# 6                             Africa           903  NaN  47.232408  female
# 69                              Asia           935  NaN   45.96873  female
# 125                           Europe           908  NaN  51.346887  female
# 177  Latin America and the Caribbean           904  NaN  49.830217  female
#
#      year
# 5    1990
# 6    1990
# 69   1990
# 125  1990
# 177  1990

# %%
f4_3 = plt.figure(figsize=(12,7))
f4_3 = sns.pointplot( x="year", y="percentage", hue="Major_area", 
              data=continents).set(title='Trends of Female Migrants Percentage of Different Contients from 1990 to 2015', xlabel ='year', ylabel ='Female Migrant Percentage')
f4_3 =plt.show()

# %%
f4_4 = plt.figure(figsize=(10,7))
f4_4 = sns.relplot(data=continents, x='year', y='percentage', hue='Major_area', kind='line',  marker='o', palette='husl', facet_kws={'sharey': False, 'sharex': True}, err_style="bars", ci=95,)
f4_4.map(sns.pointplot, 'year', 'percentage',  linestyle='', err_style="bars", color='k').set(title='Trends of Female Migrants Percentage of Different Contients with error bar from 1990 to 2015', 
                                                                                              xlabel ='year', ylabel ='Female Migrant Percentage')
f4_4
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/axisgrid.py:670: UserWarning:
#
# Using the pointplot function without specifying `order` is likely to produce an incorrect plot.

# %% [markdown]
# ### table 5

# %% [markdown]
# ###midterm

# %%
li5 = ['Sort_order','Major_area','Notes','Country_code','Type_of_data_(a)',
                'sexes_1990-1995','sexes_1995-2000','sexes_2000-2005','sexes_2005-2010','sexes_2010-2015',
                'male_1990-1995','male_1995-2000','male_2000-2005','male_2005-2010','male_2010-2015',
                'female_1990-1995','female_1995-2000','female_2000-2005','female_2005-2010','female_2010-2015',
             ]

# %%
data5 = pd.read_excel('UN_MigrantStockTotal_2015.xlsx','Table 5',header=15)
data5.columns = li5
data5
# Out:
#      Sort_order                                         Major_area Notes  \
# 0             1                                              WORLD   NaN
# 1             2                                  Developed regions   (b)
# 2             3                                 Developing regions   (c)
# 3             4                          Least developed countries   (d)
# 4             5  Less developed regions excluding least develop...   NaN
# ..          ...                                                ...   ...
# 260         261                                              Samoa   NaN
# 261         262                                            Tokelau   NaN
# 262         263                                              Tonga   NaN
# 263         264                                             Tuvalu   NaN
# 264         265                          Wallis and Futuna Islands   NaN
#
#      Country_code Type_of_data_(a) sexes_1990-1995 sexes_1995-2000  \
# ...

# %%
for col in data5.columns:
    data5.drop(data5[data5[col] == '..'].index, inplace=True)
data5
# Out:
#      Sort_order                                         Major_area Notes  \
# 0             1                                              WORLD   NaN
# 1             2                                  Developed regions   (b)
# 2             3                                 Developing regions   (c)
# 3             4                          Least developed countries   (d)
# 4             5  Less developed regions excluding least develop...   NaN
# ..          ...                                                ...   ...
# 260         261                                              Samoa   NaN
# 261         262                                            Tokelau   NaN
# 262         263                                              Tonga   NaN
# 263         264                                             Tuvalu   NaN
# 264         265                          Wallis and Futuna Islands   NaN
#
#      Country_code Type_of_data_(a) sexes_1990-1995 sexes_1995-2000  \
# ...

# %%
data5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 261 entries, 0 to 264
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Sort_order        261 non-null    int64
#  1   Major_area        261 non-null    object
#  2   Notes             26 non-null     object
#  3   Country_code      261 non-null    int64
#  4   Type_of_data_(a)  228 non-null    object
#  5   sexes_1990-1995   261 non-null    object
#  6   sexes_1995-2000   261 non-null    object
#  7   sexes_2000-2005   261 non-null    object
#  8   sexes_2005-2010   261 non-null    object
#  9   sexes_2010-2015   261 non-null    float64
#  10  male_1990-1995    261 non-null    object
#  11  male_1995-2000    261 non-null    object
#  12  male_2000-2005    261 non-null    object
#  13  male_2005-2010    261 non-null    object
#  14  male_2010-2015    261 non-null    float64
#  15  female_1990-1995  261 non-null    object
# ...

# %%
tidy_data5 = data5.melt(id_vars = ['Sort_order','Major_area','Notes','Country_code','Type_of_data_(a)'],var_name = "sex_year",value_name= "percentage")
tidy_data5
# Out:
#       Sort_order                                         Major_area Notes  \
# 0              1                                              WORLD   NaN
# 1              2                                  Developed regions   (b)
# 2              3                                 Developing regions   (c)
# 3              4                          Least developed countries   (d)
# 4              5  Less developed regions excluding least develop...   NaN
# ...          ...                                                ...   ...
# 3910         261                                              Samoa   NaN
# 3911         262                                            Tokelau   NaN
# 3912         263                                              Tonga   NaN
# 3913         264                                             Tuvalu   NaN
# 3914         265                          Wallis and Futuna Islands   NaN
#
#       Country_code Type_of_data_(a)          sex_year percentage
# ...

# %%
tidy_data5.drop(columns=['Notes','Sort_order'],axis=1,inplace=True)
tidy_data5
# Out:
#                                              Major_area  Country_code  \
# 0                                                 WORLD           900
# 1                                     Developed regions           901
# 2                                    Developing regions           902
# 3                             Least developed countries           941
# 4     Less developed regions excluding least develop...           934
# ...                                                 ...           ...
# 3910                                              Samoa           882
# 3911                                            Tokelau           772
# 3912                                              Tonga           776
# 3913                                             Tuvalu           798
# 3914                          Wallis and Futuna Islands           876
#
#      Type_of_data_(a)          sex_year percentage
# 0                 NaN   sexes_1990-1995   1.051865
# ...

# %%
tidy_data5.dropna(subset=['Type_of_data_(a)'],inplace=True)
tidy_data5
# Out:
#                      Major_area  Country_code Type_of_data_(a)  \
# 8                       Burundi           108              B R
# 9                       Comoros           174                B
# 10                     Djibouti           262              B R
# 11                      Eritrea           232                I
# 12                     Ethiopia           231              B R
# ...                         ...           ...              ...
# 3910                      Samoa           882                B
# 3911                    Tokelau           772                B
# 3912                      Tonga           776                B
# 3913                     Tuvalu           798                C
# 3914  Wallis and Futuna Islands           876                B
#
#               sex_year percentage
# 8      sexes_1990-1995  -5.355717
# 9      sexes_1990-1995  -0.199873
# 10     sexes_1990-1995  -4.058465
# 11     sexes_1990-1995   0.910748
# ...

# %%
tidy_data5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3420 entries, 8 to 3914
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Major_area        3420 non-null   object
#  1   Country_code      3420 non-null   int64
#  2   Type_of_data_(a)  3420 non-null   object
#  3   sex_year          3420 non-null   object
#  4   percentage        3420 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 160.3+ KB

# %%
tidy_data5[['sex','year']]=tidy_data5.sex_year.str.split("_",expand=True)
tidy_data5.drop(columns='sex_year',axis=1,inplace=True)
tidy_data5
# Out:
#                      Major_area  Country_code Type_of_data_(a) percentage  \
# 8                       Burundi           108              B R  -5.355717
# 9                       Comoros           174                B  -0.199873
# 10                     Djibouti           262              B R  -4.058465
# 11                      Eritrea           232                I   0.910748
# 12                     Ethiopia           231              B R  -7.179771
# ...                         ...           ...              ...        ...
# 3910                      Samoa           882                B  -0.545343
# 3911                    Tokelau           772                B    2.60325
# 3912                      Tonga           776                B   2.526318
# 3913                     Tuvalu           798                C  -1.819436
# 3914  Wallis and Futuna Islands           876                B   0.516899
#
#          sex       year
# 8      sexes  1990-1995
# 9      sexes  1990-1995
# ...

# %%
tidy_data5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3420 entries, 8 to 3914
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Major_area        3420 non-null   object
#  1   Country_code      3420 non-null   int64
#  2   Type_of_data_(a)  3420 non-null   object
#  3   percentage        3420 non-null   object
#  4   sex               3420 non-null   object
#  5   year              3420 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 187.0+ KB

# %% [markdown]
# ###final

# %%
# compare male and female
select_sex = ['male','female'] 
male_female = tidy_data5[tidy_data5['sex'].isin(select_sex)]
male_female.head()
# Out:
#      Major_area  Country_code Type_of_data_(a) percentage   sex       year
# 1313    Burundi           108              B R  -5.475511  male  1990-1995
# 1314    Comoros           174                B   -0.30906  male  1990-1995
# 1315   Djibouti           262              B R  -4.046026  male  1990-1995
# 1316    Eritrea           232                I   0.983754  male  1990-1995
# 1317   Ethiopia           231              B R  -7.179744  male  1990-1995

# %%
f5_1= plt.figure(figsize=(7,5))
f5_1 =sns.lineplot(data=male_female, x="year", y='percentage',
             hue ='sex').set(title='Annual Rate of Change of Migrant Stock by genders from 1990 to 2015', 
                                  xlabel ='Year ', ylabel ='Annual rate of change')

f5_1 = plt.show()

# %%
f5_2= plt.figure(figsize=(7,5))
f5_2 = sns.barplot(data=male_female, x="year", y='percentage',
             hue ='sex').set(title='Annual Rate of Change of Migrant Stock by genders from 1990 to 2015', 
                                  xlabel ='Year', ylabel ='Annual rate of change')

f5_2 = plt.show()

# %%
# bar and line in same plot
matplotlib.rc_file_defaults()
ax1 = sns.set_style(style=None, rc=None )

f5_3,ax1 = plt.subplots(figsize=(10,7))
f5_3 = sns.barplot(data=male_female, x="year", y='percentage',
             hue ='sex', ax=ax1)

ax2 =ax1.twinx()

f5_3 =sns.lineplot(data=male_female, x="year", y='percentage',
             hue ='sex', ax=ax2).set(title='Annual Rate of Change of Migrant Stock by genders from 1990 to 2015', 
                                  xlabel ='Year ', ylabel ='Annual rate of change')
f5_3 = plt.show()

# %% [markdown]
# ### table 6

# %% [markdown]
# ###midterm

# %%
data6 = pd.read_excel('UN_MigrantStockTotal_2015.xlsx','Table 6',header=15)

# %%
li6 = ['Sort_order','Major_area','Notes','Country_code','Type_of_data_(a)',
                'sexes_1990','sexes_1995','sexes_2000','sexes_2005','sexes_2010','sexes_2015',
                'male_1990','male_1995','male_2000','male_2005','male_2010','male_2015',
                'female_1990','female_1995','female_2000','female_2005','female_2010',
             ]
data6.columns = li6
data6
# Out:
#      Sort_order                                         Major_area Notes  \
# 0             1                                              WORLD   NaN
# 1             2                                  Developed regions   (b)
# 2             3                                 Developing regions   (c)
# 3             4                          Least developed countries   (d)
# 4             5  Less developed regions excluding least develop...   NaN
# ..          ...                                                ...   ...
# 260         261                                              Samoa   NaN
# 261         262                                            Tokelau   NaN
# 262         263                                              Tonga   NaN
# 263         264                                             Tuvalu   NaN
# 264         265                          Wallis and Futuna Islands   NaN
#
#      Country_code Type_of_data_(a) sexes_1990 sexes_1995 sexes_2000  \
# ...

# %%
data6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Sort_order        265 non-null    int64
#  1   Major_area        265 non-null    object
#  2   Notes             26 non-null     object
#  3   Country_code      265 non-null    int64
#  4   Type_of_data_(a)  232 non-null    object
#  5   sexes_1990        265 non-null    object
#  6   sexes_1995        265 non-null    object
#  7   sexes_2000        265 non-null    object
#  8   sexes_2005        265 non-null    object
#  9   sexes_2010        265 non-null    int64
#  10  sexes_2015        265 non-null    int64
#  11  male_1990         265 non-null    object
#  12  male_1995         265 non-null    object
#  13  male_2000         265 non-null    object
#  14  male_2005         265 non-null    object
#  15  male_2010         265 non-null    float64
# ...

# %%
data6.drop(columns=['Notes','Sort_order'],axis=1,inplace=True)

# %%
data6.dropna(subset=['Type_of_data_(a)'],inplace=True)

# %%
for col in data6.columns:
    data6.drop(data6[data6[col] == '..'].index, inplace=True)

# %%
tidy_data6 = data6.melt(id_vars = ['Major_area','Country_code','Type_of_data_(a)'],var_name = "sex_year",value_name= "count")
tidy_data6
# Out:
#                     Major_area  Country_code Type_of_data_(a)     sex_year  \
# 0                      Burundi           108              B R   sexes_1990
# 1                     Djibouti           262              B R   sexes_1990
# 2                     Ethiopia           231              B R   sexes_1990
# 3                        Kenya           404              B R   sexes_1990
# 4                       Malawi           454              B R   sexes_1990
# ...                        ...           ...              ...          ...
# 1899                    Canada           124                B  female_2010
# 1900  United States of America           840                B  female_2010
# 1901                 Australia            36                B  female_2010
# 1902               New Zealand           554                B  female_2010
# 1903          Papua New Guinea           598              C R  female_2010
#
#          count
# 0       267929
# 1        54508
# 2       741965
# ...

# %%
tidy_data6[['sex','year']]=tidy_data6.sex_year.str.split("_",expand=True)
tidy_data6.drop(columns='sex_year',axis=1,inplace=True)
tidy_data6
# Out:
#                     Major_area  Country_code Type_of_data_(a)     count  \
# 0                      Burundi           108              B R    267929
# 1                     Djibouti           262              B R     54508
# 2                     Ethiopia           231              B R    741965
# 3                        Kenya           404              B R     13452
# 4                       Malawi           454              B R    874614
# ...                        ...           ...              ...       ...
# 1899                    Canada           124                B -2.870071
# 1900  United States of America           840                B -1.145606
# 1901                 Australia            36                B   9.85859
# 1902               New Zealand           554                B -11.80581
# 1903          Papua New Guinea           598              C R  0.137417
#
#          sex  year
# 0      sexes  1990
# 1      sexes  1990
# 2      sexes  1990
# 3      sexes  1990
# ...

# %%
tidy_data6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1904 entries, 0 to 1903
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Major_area        1904 non-null   object
#  1   Country_code      1904 non-null   int64
#  2   Type_of_data_(a)  1904 non-null   object
#  3   count             1904 non-null   object
#  4   sex               1904 non-null   object
#  5   year              1904 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 89.4+ KB

# %% [markdown]
# tidy_data6.sort_values(by=['Country_code'], inplace=True)
# tidy_data6

# %% [markdown]
# ###final

# %%
# midterm data cleaning is not correct, redo the data cleaning
data6 = pd.read_excel('UN_MigrantStockTotal_2015.xlsx','Table 6',header=15)
li6 = ['Sort_order','Major_area','Notes','Country_code','Type_of_data_(a)',
                'stock_1990','stock_1995','stock_2000','stock_2005','stock_2010','stock_2015',
                'percentage_1990','percentage_1995','percentage_2000','percentage_2005','percentage_2010','percentage_2015',
                'annual%change_1990-1995','annual%change_1995-2000','annual%change_2000-2005','annual%change_2005-2010','annual%change_2010-2015',
             ]
data6.columns = li6
data6.head()
# Out:
#    Sort_order                                         Major_area Notes  \
# 0           1                                              WORLD   NaN
# 1           2                                  Developed regions   (b)
# 2           3                                 Developing regions   (c)
# 3           4                          Least developed countries   (d)
# 4           5  Less developed regions excluding least develop...   NaN
#
#    Country_code Type_of_data_(a) stock_1990 stock_1995 stock_2000 stock_2005  \
# 0           900              NaN   18836571   17853840   15827803   13276733
# 1           901              NaN    2014564    3609670    2997256    2361229
# 2           902              NaN   16822007   14244170   12830547   10915504
# 3           941              NaN    5048391    5160131    3047488    2363782
# 4           934              NaN   11773616    9084039    9783059    8551722
#
#    stock_2010  ...  percentage_1995 percentage_2000 percentage_2005  \
# ...

# %%
data6.dropna(subset=['Type_of_data_(a)'],inplace=True)
data6.head()
# Out:
#     Sort_order Major_area Notes  Country_code Type_of_data_(a) stock_1990  \
# 8            9    Burundi   NaN           108              B R     267929
# 9           10    Comoros   NaN           174                B          0
# 10          11   Djibouti   NaN           262              B R      54508
# 11          12    Eritrea   NaN           232                I          0
# 12          13   Ethiopia   NaN           231              B R     741965
#
#    stock_1995 stock_2000 stock_2005  stock_2010  ...  percentage_1995  \
# 8      173017      27136      20681       29365  ...         67.88894
# 9           5         10          5           0  ...         0.035871
# 10      27310      23257      10456       15104  ...         27.37186
# 11       1083       1984       4418        4809  ...         8.733871
# 12     393479     197959     100817      154295  ...        48.764041
#
#    percentage_2000 percentage_2005 percentage_2010 percentage_2015  \
# ...

# %%
data6.drop(columns=['Sort_order','Country_code','Notes','Type_of_data_(a)'],axis=1,inplace=True)
for col in data6.columns:
    data6.drop(data6[data6[col] == '..'].index, inplace=True)
data6.head()
# Out:
#    Major_area stock_1990 stock_1995 stock_2000 stock_2005  stock_2010  \
# 8     Burundi     267929     173017      27136      20681       29365
# 10   Djibouti      54508      27310      23257      10456       15104
# 12   Ethiopia     741965     393479     197959     100817      154295
# 13      Kenya      13452     234665     206106     251271      402905
# 15     Malawi     874614       1018       3900       4240        5740
#
#     stock_2015 percentage_1990 percentage_1995 percentage_2000  \
# 8        47805        80.43259        67.88894        21.60028
# 10       20530       44.597901        27.37186       23.139682
# 12      659524        64.21771       48.764041       32.378832
# 13      551352        4.524844       37.925963       29.479975
# 15        5844       77.555679        0.421316        1.676554
#
#    percentage_2005  percentage_2010  percentage_2015 annual%change_1990-1995  \
# 8        11.963048        12.481988        16.667829               -3.390926
# ...

# %%
tidy_data6 = data6.melt(id_vars = ['Major_area'],var_name = "refugee_year",value_name= "count")
tidy_data6.head()
# Out:
#   Major_area refugee_year   count
# 0    Burundi   stock_1990  267929
# 1   Djibouti   stock_1990   54508
# 2   Ethiopia   stock_1990  741965
# 3      Kenya   stock_1990   13452
# 4     Malawi   stock_1990  874614

# %%
tidy_data6[['refugee','year']]=tidy_data6.refugee_year.str.split("_",expand=True)
tidy_data6.drop(columns='refugee_year',axis=1,inplace=True)
tidy_data6.head()
# Out:
#   Major_area   count refugee  year
# 0    Burundi  267929   stock  1990
# 1   Djibouti   54508   stock  1990
# 2   Ethiopia  741965   stock  1990
# 3      Kenya   13452   stock  1990
# 4     Malawi  874614   stock  1990

# %% [markdown]
# ###Refugees as a percentage of the international migrant stock

# %%
select2 = ['percentage'] 
percentage = tidy_data6[tidy_data6['refugee'].isin(select2)]
percentage.head()
# Out:
#     Major_area      count     refugee  year
# 672    Burundi   80.43259  percentage  1990
# 673   Djibouti  44.597901  percentage  1990
# 674   Ethiopia   64.21771  percentage  1990
# 675      Kenya   4.524844  percentage  1990
# 676     Malawi  77.555679  percentage  1990

# %%
f6_2 = plt.figure(figsize = (7,5))
f6_2 = sns.lineplot(
    data=percentage, x="year", y="count", 
).set(title='Trend of Refugees as a percentage of the international migrant stock by Countries from 1990 to 2015', 
                                  xlabel ='Year', ylabel =' percentage of Refugees')
f6_2 = plt.show()

# %% [markdown]
# ###Aunal Rate of Change

# %%
select3 = ['annual%change'] 
Annual_change = tidy_data6[tidy_data6['refugee'].isin(select3)]
Annual_change
# Out:
#                     Major_area       count        refugee       year
# 1344                   Burundi   -3.390926  annual%change  1990-1995
# 1345                  Djibouti   -9.763426  annual%change  1990-1995
# 1346                  Ethiopia   -5.505717  annual%change  1990-1995
# 1347                     Kenya   42.521055  annual%change  1990-1995
# 1348                    Malawi -104.307376  annual%change  1990-1995
# ...                        ...         ...            ...        ...
# 1899                    Canada   -2.870071  annual%change  2010-2015
# 1900  United States of America   -1.145606  annual%change  2010-2015
# 1901                 Australia     9.85859  annual%change  2010-2015
# 1902               New Zealand   -11.80581  annual%change  2010-2015
# 1903          Papua New Guinea    0.137417  annual%change  2010-2015
#
# [560 rows x 4 columns]

# %%
f6_2 = plt.figure(figsize = (10,6))
f6_2= sns.boxenplot(data=Annual_change, x="count", y="year").set(title='Aunal Rate of Change in each year from 1990 to 2015', 
                                  xlabel ='Annual rate of change', ylabel ='Year')

f6_2 = plt.show()
